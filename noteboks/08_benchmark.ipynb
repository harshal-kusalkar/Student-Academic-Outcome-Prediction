# %%
import os
from pathlib import Path

# %%
os.chdir("..")

# %%
print(os.getcwd())
# Out:
# e:\project_archive\student-dropout-enrolled-graduate-rate-prediction

# %%
# load X_train and y_train
import pandas as pd 
import numpy as np

X_train_path = Path("data/processed/X_train.csv")
y_train_path = Path("data/processed/y_train.npy")

X_train = pd.read_csv(X_train_path)
y_train = np.load(y_train_path)

print(f"X_train loaded successfully: {X_train.shape}")
print(f"y_train loaded successfully: {len(y_train)}")
# Out:
# X_train loaded successfully: (3539, 1)
# y_train loaded successfully: 3539
